# %%
from __future__ import print_function, division
import pandas as pd
import pylab as pl

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#!curl -O 'https://www.foreignlaborcert.doleta.gov/docs/py2014q4/H-1B_FY14_Q4.xlsx'

# %%
h1b_data = pd.read_excel('H-1B_FY14_Q4.xlsx')

# %%
h1b_data.head()
# Out:
#       LCA_CASE_NUMBER               STATUS     LCA_CASE_SUBMIT  \
# 0  I-200-09106-546545  CERTIFIED-WITHDRAWN 2013-01-18 18:05:43
# 1  I-200-09162-143337            CERTIFIED 2014-03-17 11:11:45
# 2  I-200-09182-550211               DENIED 2014-03-14 17:05:01
# 3  I-200-09193-873099            CERTIFIED 2014-03-01 12:37:02
# 4  I-200-09197-120609  CERTIFIED-WITHDRAWN 2014-03-10 15:33:41
#
#         DECISION_DATE VISA_CLASS LCA_CASE_EMPLOYMENT_START_DATE  \
# 0 2014-09-29 15:59:50       H-1B                     2013-02-01
# 1 2014-03-21 23:11:51       H-1B                     2014-09-15
# 2 2014-03-20 16:59:49       H-1B                     2014-04-01
# 3 2014-03-06 22:03:37       H-1B                     2014-08-28
# 4 2014-03-17 10:52:46       H-1B                     2014-09-01
#
#   LCA_CASE_EMPLOYMENT_END_DATE             LCA_CASE_EMPLOYER_NAME  \
# 0                   2016-02-01  TEXAS STATE UNIVERSITY-SAN MARCOS
# ...

# %% [markdown]
# ### Section 1

# %% [markdown]
# #### 1. Which companies applied for the largest number of H1B visas where the job opening was located in NYC? Please describe any issues you may encounter summarizing the data by employer name.

# %%
h1b_NewYork = h1b_data[h1b_data['LCA_CASE_EMPLOYER_CITY'] == 'NEW YORK'] #new dataframe - NY data 
h1b_NewYork
# Out:
#            LCA_CASE_NUMBER               STATUS     LCA_CASE_SUBMIT  \
# 35      I-200-09300-229787  CERTIFIED-WITHDRAWN 2013-09-11 15:35:19
# 42      I-200-09321-521235  CERTIFIED-WITHDRAWN 2012-05-02 17:55:25
# 61      I-200-10022-756568            CERTIFIED 2013-10-24 20:48:23
# 86      I-200-10078-083188  CERTIFIED-WITHDRAWN 2011-04-07 18:15:16
# 97      I-200-10106-798993            CERTIFIED 2014-05-20 11:31:44
# 142     I-200-10200-339052  CERTIFIED-WITHDRAWN 2010-07-19 13:43:18
# 165     I-200-10239-739818            CERTIFIED 2014-03-07 14:40:01
# 181     I-200-10252-617966            WITHDRAWN 2010-09-10 16:06:44
# 194     I-200-10263-223878  CERTIFIED-WITHDRAWN 2010-09-20 16:40:10
# 198     I-200-10264-536122  CERTIFIED-WITHDRAWN 2010-09-21 18:25:09
# 209     I-200-10267-931078  CERTIFIED-WITHDRAWN 2010-09-30 14:27:39
# 220     I-200-10274-218024  CERTIFIED-WITHDRAWN 2010-10-06 16:05:06
# 224     I-200-10277-245354  CERTIFIED-WITHDRAWN 2010-10-04 16:31:46
# ...

# %%
#companies applied for the largest number of H1B in NYC 
h1b_NewYork['count'] = 1
employer_count = h1b_NewYork[['LCA_CASE_EMPLOYER_NAME','count']]
top = employer_count.groupby('LCA_CASE_EMPLOYER_NAME').count().sort(columns='count', ascending=False).head(20)
print ('Top NYC employers who sponsor H1B:')
print (' ')
for e, c in zip(top.index, top['count']):
    print ('{0} | {1}'.format(e, c))
# Out:
# Top NYC employers who sponsor H1B:
#
# MPHASIS CORPORATION | 946
# GOLDMAN, SACHS & CO. | 610
# MORGAN STANLEY & CO. LLC | 438
# CITIBANK, N.A. | 414
# BLOOMBERG, LP | 371
# CREDIT SUISSE SECURITIES (USA) LLC | 365
# COLUMBIA UNIVERSITY | 311
# CITIGROUP GLOBAL MARKETS INC. | 284
# DEUTSCHE BANK SECURITIES INC. | 230
# BARCLAYS SERVICES CORP. | 228
# GOLDMAN SACHS & CO. | 226
# AMERICAN EXPRESS TRAVEL RELATED SERVICES COMPANY, | 226
# MOUNT SINAI MEDICAL CENTER | 226
# MCKINSEY & COMPANY, INC. UNITED STATES | 183
# BLACKROCK FINANCIAL MANAGEMENT, INC. | 177
# MEMORIAL SLOAN-KETTERING CANCER CENTER | 162
# NEW YORK UNIVERSITY SCHOOL OF MEDICINE | 157
# BARCLAYS CAPITAL INC. | 155
# NEW YORK UNIVERSITY | 149
# WEILL CORNELL MEDICAL COLLEGE | 138
# C:\Users\akali\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# #### Issues:
# One of the issues for summurizing the data by employer name is different format of company names

# %% [markdown]
# ---

# %% [markdown]
# #### 2. Calculate the mean and standard deviation of wages proposed for workers located in New York City and Mountain View. Are the average wages in these two locations statistically different? What factors could explain the results?

# %%
h1b_NewYork.columns
# Out:
# Index([               u'LCA_CASE_NUMBER',                         u'STATUS',
#                       u'LCA_CASE_SUBMIT',                  u'DECISION_DATE',
#                            u'VISA_CLASS', u'LCA_CASE_EMPLOYMENT_START_DATE',
#          u'LCA_CASE_EMPLOYMENT_END_DATE',         u'LCA_CASE_EMPLOYER_NAME',
#             u'LCA_CASE_EMPLOYER_ADDRESS',         u'LCA_CASE_EMPLOYER_CITY',
#               u'LCA_CASE_EMPLOYER_STATE',  u'LCA_CASE_EMPLOYER_POSTAL_CODE',
#                     u'LCA_CASE_SOC_CODE',              u'LCA_CASE_SOC_NAME',
#                    u'LCA_CASE_JOB_TITLE',        u'LCA_CASE_WAGE_RATE_FROM',
#                 u'LCA_CASE_WAGE_RATE_TO',        u'LCA_CASE_WAGE_RATE_UNIT',
#                         u'FULL_TIME_POS',                  u'TOTAL_WORKERS',
#                u'LCA_CASE_WORKLOC1_CITY',        u'LCA_CASE_WORKLOC1_STATE',
#                                  u'PW_1',                      u'PW_UNIT_1',
# ...

# %%
h1b_NewYork['LCA_CASE_WAGE_RATE_FROM'].mean() #calculation of mean for NY
# Out:
# 87223.49853663126

# %%
h1b_NewYork['LCA_CASE_WAGE_RATE_FROM'].std() #calculation of standard deviation for NY
# Out:
# 130043.98174564072

# %%
h1b_MountainView = h1b_data[h1b_data['LCA_CASE_EMPLOYER_CITY'] == 'MOUNTAIN VIEW'] #Mountain View data
h1b_MountainView
# Out:
#            LCA_CASE_NUMBER               STATUS     LCA_CASE_SUBMIT  \
# 285     I-200-10299-087885            WITHDRAWN 2010-10-27 15:57:47
# 361     I-200-10315-627458  CERTIFIED-WITHDRAWN 2010-11-11 20:13:20
# 993     I-200-11055-204236  CERTIFIED-WITHDRAWN 2011-02-24 19:58:29
# 1089    I-200-11063-068354            WITHDRAWN 2011-03-04 20:33:46
# 1101    I-200-11063-762427            WITHDRAWN 2011-03-04 20:20:35
# 1294    I-200-11074-036949  CERTIFIED-WITHDRAWN 2011-03-15 14:46:27
# 1647    I-200-11089-186173            WITHDRAWN 2011-03-30 16:31:46
# 1755    I-200-11095-883070  CERTIFIED-WITHDRAWN 2011-04-05 12:57:57
# 1813    I-200-11098-072966            WITHDRAWN 2011-04-15 19:43:29
# 1851    I-200-11101-672641  CERTIFIED-WITHDRAWN 2011-04-15 11:35:58
# 1905    I-200-11104-325565  CERTIFIED-WITHDRAWN 2011-04-20 17:05:15
# 2033    I-200-11112-451064            WITHDRAWN 2011-04-25 10:49:51
# 2072    I-200-11116-609814  CERTIFIED-WITHDRAWN 2011-07-01 17:11:09
# ...

# %%
h1b_MountainView['LCA_CASE_WAGE_RATE_FROM'].mean()#calculation of mean for MV
# Out:
# 117821.95901840494

# %%
h1b_MountainView['LCA_CASE_WAGE_RATE_FROM'].std()#calculation of standard deviation for MV
# Out:
# 35833.256730078974

# %%
NY_mean = h1b_NewYork['LCA_CASE_WAGE_RATE_FROM'].mean()
print ('NY mean:', NY_mean)
MV_mean = h1b_MountainView['LCA_CASE_WAGE_RATE_FROM'].mean()
print ('MV mean:', MV_mean)
# Out:
# NY mean: 87223.4985366
# MV mean: 117821.959018

# %%
NY_cases = h1b_NewYork['LCA_CASE_NUMBER'].count()
MV_cases = h1b_MountainView['LCA_CASE_NUMBER'].count()
print ('NY cases:', NY_cases)
print ('MV cases:', MV_cases)
# Out:
# NY cases: 26522
# MV cases: 5379

# %% [markdown]
# The average wages for NY and MV are different, but number of cases in NY is almost 5 times biger than number of cases in MV. If we look into results of standard deviation for proposed wages for both locations, it is clear that NY wages is widely distributed about the mean, while MV wages are clustered about the mean.

# %% [markdown]
# ---

# %% [markdown]
# ### Section 2 & 3

# %%
#All States H1B visa stauses

# %%
h1b_visa_status_all = list(h1b_data['STATUS'].unique())

print ('H1B Visa Statuses in All Cities')
print (' ')
for v in h1b_visa_status_all:
    print ('Number of {0} is: {1}'.format(v, len(h1b_data[h1b_data['STATUS'] == v])))
# Out:
# H1B Visa Statuses in All Cities
#
# Number of CERTIFIED-WITHDRAWN is: 36350
# Number of CERTIFIED is: 455144
# Number of DENIED is: 11938
# Number of WITHDRAWN is: 16069
# Number of REJECTED is: 2
# Number of INVALIDATED is: 1

# %%
#H1B visa stauses in New York

# %%
h1b_visa_status_NY= list(h1b_data['STATUS'].unique())

print ('H1B Visa Statuses in New York')
print (' ')
for v in h1b_visa_status_NY:
    print ('Number of {0} is: {1}'.format(v, len(h1b_NewYork[h1b_NewYork['STATUS'] == v])))
# Out:
# H1B Visa Statuses in New York
#
# Number of CERTIFIED-WITHDRAWN is: 2338
# Number of CERTIFIED is: 22304
# Number of DENIED is: 882
# Number of WITHDRAWN is: 998
# Number of REJECTED is: 0
# Number of INVALIDATED is: 0

# %%
#Top H1B Jobs in the U.S.

# %%
h1b_data['count'] = 1
employer_count = h1b_data[['LCA_CASE_JOB_TITLE','count']]
top = employer_count.groupby('LCA_CASE_JOB_TITLE').count().sort(columns='count', ascending=False).head(20)
print ('Top Jobs:')
print (' ')
for e, c in zip(top.index, top['count']):
    print ('{0} | {1}'.format(e, c))
# Out:
# Top Jobs:
#
# PROGRAMMER ANALYST | 43114
# SOFTWARE ENGINEER | 20500
# COMPUTER PROGRAMMER | 14950
# SYSTEMS ANALYST | 10196
# SOFTWARE DEVELOPER | 7337
# BUSINESS ANALYST | 7302
# COMPUTER SYSTEMS ANALYST | 6821
# TECHNOLOGY LEAD - US | 5057
# TECHNOLOGY ANALYST - US | 4913
# SENIOR CONSULTANT | 4898
# SENIOR SOFTWARE ENGINEER | 4685
# CONSULTANT | 4375
# ASSISTANT PROFESSOR | 4305
# PROJECT MANAGER | 3331
# PHYSICAL THERAPIST | 2984
# WEB DEVELOPER | 2948
# DATABASE ADMINISTRATOR | 2811
# COMPUTER SYSTEMS ENGINEER | 2481
# SYSTEMS ENGINEER - US | 2463
# ASSOCIATE | 2382
# C:\Users\akali\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()

# %%
#Top H1B Jobs in NYC

# %%
h1b_NewYork['count'] = 1
employer_count = h1b_NewYork[['LCA_CASE_JOB_TITLE','count']]
top = employer_count.groupby('LCA_CASE_JOB_TITLE').count().sort(columns='count', ascending=False).head(20)
print ('Top H1B Jobs in NYC:')
print (' ')
for e, c in zip(top.index, top['count']):
    print ('{0} | {1}'.format(e, c))
# Out:
# Top H1B Jobs in NYC:
#
# ASSOCIATE | 977
# ANALYST | 875
# SOFTWARE ENGINEER | 530
# VICE PRESIDENT | 377
# PROGRAMMER ANALYST | 374
# SOFTWARE DEVELOPER | 261
# TECHNICAL ANALYST | 252
# COMPUTER SPECIALIST | 244
# SYSTEMS ANALYST | 238
# SENIOR SOFTWARE DEVELOPER | 212
# FINANCIAL ANALYST | 212
# ASSISTANT VICE PRESIDENT | 204
# BUSINESS ANALYST | 201
# ACCOUNTANT | 186
# SENIOR SOFTWARE ENGINEER | 175
# MARKET RESEARCH ANALYST | 174
# GRAPHIC DESIGNER | 166
# SENIOR SYSTEMS ANALYST | 166
# PROJECT MANAGER | 163
# RESEARCH ASSOCIATE | 154
# C:\Users\akali\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# ...

# %%
#H1B Visa cases by State

# %%
h1b_data['count'] = 1
employer_count = h1b_data[['LCA_CASE_EMPLOYER_STATE','count']]
top = employer_count.groupby('LCA_CASE_EMPLOYER_STATE').count().sort(columns='count', ascending=False).head(20)
print ('Top H1B Visa cases by State:')
print (' ')
for e, c in zip(top.index, top['count']):
    print ('{0} | {1}'.format(e, c))
# Out:
# Top H1B Visa cases by State:
#
# CA | 89259
# TX | 72892
# NJ | 67321
# NY | 39252
# IL | 28924
# PA | 23005
# MD | 21678
# MA | 18303
# MI | 18047
# VA | 17844
# FL | 14369
# NC | 14070
# GA | 13887
# WA | 12001
# OH | 8002
# CT | 5776
# MO | 4188
# MN | 3998
# TN | 3981
# CO | 3586
# C:\Users\akali\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()

# %%
#Decision period

# %%
h1b_data['decision_period'] = (h1b_data['DECISION_DATE'] - h1b_data['LCA_CASE_SUBMIT']).dt.days

# %%
dec_per_max = h1b_data['decision_period'].max()
dec_per_min = h1b_data['decision_period'].min()
dec_mean = h1b_data['decision_period'].mean()
dec_std = h1b_data['decision_period'].std()
print ('Max days for decision:', dec_per_max)
print ('Min days for decison:', dec_per_min)
print ('Average days for decision:', dec_mean)
print ('Standard  deviation:', dec_std)
# Out:
# Max days for decision: 1747
# Min days for decison: 0
# Average days for decision: 34.5281287536
# Standard  deviation: 136.54991934

# %%
#Decision period for NYC

# %%
h1b_NewYork['decision_period'] = (h1b_NewYork['DECISION_DATE'] - h1b_NewYork['LCA_CASE_SUBMIT']).dt.days
# Out:
# C:\Users\akali\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
dec_per_max = h1b_NewYork['decision_period'].max()
dec_per_min = h1b_NewYork['decision_period'].min()
dec_mean = h1b_NewYork['decision_period'].mean()
dec_std = h1b_NewYork['decision_period'].std()
print ('Max days for decision:', dec_per_max)
print ('Min days for decison:', dec_per_min)
print ('Average days for decision:', dec_mean)
print ('Standard  deviation:', dec_std)
# Out:
# Max days for decision: 1278
# Min days for decison: 0
# Average days for decision: 48.5807254355
# Standard  deviation: 170.377423638
